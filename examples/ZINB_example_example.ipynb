# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/StatMixedML/LightGBMLSS/blob/master/examples/ZINB_example_example.ipynb)

# %% [markdown]
# # Imports

# %%
from lightgbmlss.model import *
from lightgbmlss.distributions.ZINB import *

from sklearn.model_selection import train_test_split
import pandas as pd
import plotnine
from plotnine import *
plotnine.options.figure_size = (18, 9)

# %% [markdown]
# # Data

# %%
# For more information on the dataset see: https://stats.oarc.ucla.edu/stata/dae/zero-inflated-poisson-regression/
data = pd.read_stata("http://www.stata-press.com/data/r10/fish.dta")
y = data["count"].values
X = data.drop(columns="count")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

dtrain = lgb.Dataset(X_train, label=y_train)

# %% [markdown]
# # Distribution Selection

# %%
# Specifies Zero-Inflated Negative Binomial distribution. See ?ZINB for an overview.
lgblss = LightGBMLSS(
    ZINB(stabilization="None",              # Options are "None", "MAD", "L2".
         response_fn_total_count="relu",    # Function to transform the total_count-parameter, e.g., "exp", "softplus" or "relu".
         response_fn_probs="sigmoid",       # Function to transform the probs-parameter, e.g., "sigmoid",
         loss_fn="nll"                      # Function to transform the concentration and rate parameters, e.g., "exp" or "softplus".
        )
)

# %% [markdown]
# # Hyper-Parameter Optimization

# %%
# Any LightGBM hyperparameter can be tuned, where the structure of the parameter dictionary needs to be as follows:

    # Float/Int sample_type
        # {"param_name": ["sample_type", low, high, log]}
            # sample_type: str, Type of sampling, e.g., "float" or "int"
            # low: int, Lower endpoint of the range of suggested values
            # high: int, Upper endpoint of the range of suggested values
            # log: bool, Flag to sample the value from the log domain or not
    # Example: {"eta": "float", low=1e-5, high=1, log=True]}

    # Categorical sample_type
        # {"param_name": ["sample_type", ["choice1", "choice2", "choice3", "..."]]}
            # sample_type: str, Type of sampling, either "categorical"
            # choice1, choice2, choice3, ...: str, Possible choices for the parameter
        # Example: {"boosting": ["categorical", ["gbdt", "dart"]]}

    # For parameters without tunable choice (this is needed if tree_method = "gpu_hist" and gpu_id needs to be specified)
        # {"param_name": ["none", [value]]},
        # param_name: str, Name of the parameter
        # value: int, Value of the parameter
    # Example: {"gpu_id": ["none", [0]]}

param_dict = {
    "eta":                      ["float", {"low": 1e-5,   "high": 1,     "log": True}],
    "max_depth":                ["int",   {"low": 1,      "high": 10,    "log": False}],
    "min_gain_to_split":        ["float", {"low": 1e-8,   "high": 40,    "log": False}],
    "subsample":                ["float", {"low": 0.2,    "high": 1.0,   "log": False}],
    "feature_fraction":         ["float", {"low": 0.2,    "high": 1.0,   "log": False}],
    "boosting":                 ["categorical", ["gbdt"]],
}

np.random.seed(123)
opt_param = lgblss.hyper_opt(param_dict,
                             dtrain,
                             num_boost_round=100,        # Number of boosting iterations.
                             nfold=5,                    # Number of cv-folds.
                             early_stopping_rounds=20,   # Number of early-stopping rounds
                             max_minutes=5,              # Time budget in minutes, i.e., stop study after the given number of minutes.
                             n_trials=None,              # The number of trials. If this argument is set to None, there is no limitation on the number of trials.
                             silence=False,              # Controls the verbosity of the trail, i.e., user can silence the outputs of the trail.
                             seed=123,                   # Seed used to generate cv-folds.
                             hp_seed=None                # Seed for random number generator used in the Bayesian hyperparameter search.
                             )
# Out:
# [I 2023-06-15 15:04:22,084] A new study created in memory with name: LightGBMLSS Hyper-Parameter Optimization
# C:\Users\maerzale\.virtualenvs\LightGBMLSS-Dam57Fpb\lib\site-packages\optuna\progress_bar.py:56: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#    0%|          | 00:00/05:00
# [I 2023-06-15 15:04:25,963] Trial 0 finished with value: 73.10546734431021 and parameters: {'eta': 0.321402498698913, 'max_depth': 9, 'min_gain_to_split': 28.18053609091286, 'subsample': 0.6819725345892192, 'feature_fraction': 0.3820453961440182, 'boosting': 'gbdt'}. Best is trial 0 with value: 73.10546734431021.
# [I 2023-06-15 15:04:32,260] Trial 1 finished with value: 60.37888041476175 and parameters: {'eta': 0.0447055831671884, 'max_depth': 9, 'min_gain_to_split': 7.573180441386256, 'subsample': 0.6409597630759871, 'feature_fraction': 0.25689884199533897, 'boosting': 'gbdt'}. Best is trial 1 with value: 60.37888041476175.
# [I 2023-06-15 15:04:37,943] Trial 2 finished with value: 72.50112287915071 and parameters: {'eta': 1.34726908982569e-05, 'max_depth': 2, 'min_gain_to_split': 10.574946217343324, 'subsample': 0.2573628009606715, 'feature_fraction': 0.4618919521671847, 'boosting': 'gbdt'}. Best is trial 1 with value: 60.37888041476175.
# [I 2023-06-15 15:04:41,928] Trial 3 finished with value: 66.43135707312096 and parameters: {'eta': 0.009353082137583669, 'max_depth': 10, 'min_gain_to_split': 37.77095364303893, 'subsample': 0.9031258790779055, 'feature_fraction': 0.4786691670891974, 'boosting': 'gbdt'}. Best is trial 1 with value: 60.37888041476175.
# [I 2023-06-15 15:04:42,931] Trial 4 finished with value: 72.56043793020781 and parameters: {'eta': 0.7577208022086581, 'max_depth': 9, 'min_gain_to_split': 23.87383041404277, 'subsample': 0.8353126354738418, 'feature_fraction': 0.20488776681609286, 'boosting': 'gbdt'}. Best is trial 1 with value: 60.37888041476175.
# [I 2023-06-15 15:04:43,953] Trial 5 finished with value: 81.38053139875971 and parameters: {'eta': 0.4062038050625299, 'max_depth': 2, 'min_gain_to_split': 25.770355924026816, 'subsample': 0.9635390472202581, 'feature_fraction': 0.8987992694712528, 'boosting': 'gbdt'}. Best is trial 1 with value: 60.37888041476175.
# [I 2023-06-15 15:04:45,347] Trial 6 finished with value: 65.05185345987417 and parameters: {'eta': 0.040425250863485945, 'max_depth': 2, 'min_gain_to_split': 24.374397750547548, 'subsample': 0.3487120950279319, 'feature_fraction': 0.8917892391353743, 'boosting': 'gbdt'}. Best is trial 1 with value: 60.37888041476175.
# [I 2023-06-15 15:04:47,912] Trial 7 finished with value: 51.482622696878124 and parameters: {'eta': 0.35971163183044724, 'max_depth': 1, 'min_gain_to_split': 0.3264294887979989, 'subsample': 0.3177509372133446, 'feature_fraction': 0.5336394908054578, 'boosting': 'gbdt'}. Best is trial 7 with value: 51.482622696878124.
# [I 2023-06-15 15:04:53,009] Trial 8 finished with value: 56.667804575931406 and parameters: {'eta': 0.0365562605536056, 'max_depth': 10, 'min_gain_to_split': 3.7324341495280517, 'subsample': 0.49960677227210903, 'feature_fraction': 0.8641972069763952, 'boosting': 'gbdt'}. Best is trial 7 with value: 51.482622696878124.
# [I 2023-06-15 15:04:54,283] Trial 9 finished with value: 75.01290258832606 and parameters: {'eta': 0.33403828884154974, 'max_depth': 3, 'min_gain_to_split': 13.973036032275216, 'subsample': 0.8524942935670541, 'feature_fraction': 0.7018198528399753, 'boosting': 'gbdt'}. Best is trial 7 with value: 51.482622696878124.
# [I 2023-06-15 15:04:55,661] Trial 10 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:05
pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:04,808] Trial 76 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:05,950] Trial 77 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:07,079] Trial 78 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:08,176] Trial 79 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:09,295] Trial 80 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:10,389] Trial 81 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:12,587] Trial 82 pruned. Trial was pruned at iteration 42.
# [I 2023-06-15 15:07:14,428] Trial 83 pruned. Trial was pruned at iteration 36.
# [I 2023-06-15 15:07:15,569] Trial 84 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:16,664] Trial 85 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:17,796] Trial 86 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:20,101] Trial 87 pruned. Trial was pruned at iteration 41.
# [I 2023-06-15 15:07:21,252] Trial 88 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:22,373] Trial 89 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:23,506] Trial 90 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:26,118] Trial 91 finished with value: 51.74194820198251 and parameters: {'eta': 0.22307252589928223, 'max_depth': 1, 'min_gain_to_split': 1.5072233144771916, 'subsample': 0.34429619636252373, 'feature_fraction': 0.8372431602567098, 'boosting': 'gbdt'}. Best is trial 52 with value: 48.00996222527442.
# [I 2023-06-15 15:07:28,115] Trial 92 pruned. Trial was pruned at iteration 36.
# [I 2023-06-15 15:07:30,132] Trial 93 pruned. Trial was pruned at iteration 38.
# [I 2023-06-15 15:07:31,337] Trial 94 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:32,435] Trial 95 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:33,718] Trial 96 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:34,868] Trial 97 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:35,944] Trial 98 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:37,187] Trial 99 pruned. Trial was pruned at iteration 21.
# [I 2023-06-15 15:07:38,540] Trial 100 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:43,047] Trial 101 finished with value: 49.547926473459846 and parameters: {'eta': 0.20252963563131543, 'max_depth': 1, 'min_gain_to_split': 0.965837875540547, 'subsample': 0.3371317984972352, 'feature_fraction': 0.830553855323377, 'boosting': 'gbdt'}. Best is trial 52 with value: 48.00996222527442.
# [I 2023-06-15 15:07:44,226] Trial 102 pruned. Trial was pruned at iteration 21.
# [I 2023-06-15 15:07:45,304] Trial 103 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:46,400] Trial 104 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:47,640] Trial 105 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:07:53,339] Trial 106 finished with value: 47.873158745475166 and parameters: {'eta': 0.09389989041224552, 'max_depth': 5, 'min_gain_to_split': 0.0008642890308526163, 'subsample': 0.41821723080789425, 'feature_fraction': 0.7623699794860095, 'boosting': 'gbdt'}. Best is trial 106 with value: 47.873158745475166.
# [I 2023-06-15 15:07:56,854] Trial 107 finished with value: 50.729632477948186 and parameters: {'eta': 0.111588384243821, 'max_depth': 2, 'min_gain_to_split': 0.7003243031199575, 'subsample': 0.3729814093751013, 'feature_fraction': 0.7875392940491823, 'boosting': 'gbdt'}. Best is trial 106 with value: 47.873158745475166.
# [I 2023-06-15 15:07:57,995] Trial 108 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:01,278] Trial 109 finished with value: 47.76294404698272 and parameters: {'eta': 0.11822840706436007, 'max_depth': 2, 'min_gain_to_split': 0.8165464594469042, 'subsample': 0.45276400454388877, 'feature_fraction': 0.7945577994601252, 'boosting': 'gbdt'}. Best is trial 109 with value: 47.76294404698272.
# [I 2023-06-15 15:08:02,368] Trial 110 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:03,451] Trial 111 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:04,541] Trial 112 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:05,709] Trial 113 pruned. Trial was pruned at iteration 21.
# [I 2023-06-15 15:08:06,796] Trial 114 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:07,978] Trial 115 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:09,055] Trial 116 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:10,189] Trial 117 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:11,539] Trial 118 pruned. Trial was pruned at iteration 24.
# [I 2023-06-15 15:08:16,674] Trial 119 finished with value: 48.983390784147616 and parameters: {'eta': 0.09875729875825943, 'max_depth': 2, 'min_gain_to_split': 0.023368445301634844, 'subsample': 0.3938204706160181, 'feature_fraction': 0.8885912005374397, 'boosting': 'gbdt'}. Best is trial 109 with value: 47.76294404698272.
# [I 2023-06-15 15:08:17,918] Trial 120 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:19,107] Trial 121 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:20,366] Trial 122 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:21,518] Trial 123 pruned. Trial was pruned at iteration 21.
# [I 2023-06-15 15:08:22,649] Trial 124 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:23,818] Trial 125 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:24,925] Trial 126 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:26,019] Trial 127 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:27,177] Trial 128 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:28,355] Trial 129 pruned. Trial was pruned at iteration 21.
# [I 2023-06-15 15:08:29,437] Trial 130 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:31,436] Trial 131 finished with value: 48.55895709951165 and parameters: {'eta': 0.5852342844324627, 'max_depth': 1, 'min_gain_to_split': 0.040354935921229865, 'subsample': 0.3101540399422072, 'feature_fraction': 0.7821763933865185, 'boosting': 'gbdt'}. Best is trial 109 with value: 47.76294404698272.
# [I 2023-06-15 15:08:32,519] Trial 132 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:33,616] Trial 133 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:34,712] Trial 134 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:35,809] Trial 135 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:36,915] Trial 136 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:38,054] Trial 137 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:39,169] Trial 138 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:40,400] Trial 139 pruned. Trial was pruned at iteration 21.
# [I 2023-06-15 15:08:41,646] Trial 140 pruned. Trial was pruned at iteration 21.
# [I 2023-06-15 15:08:42,916] Trial 141 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:44,028] Trial 142 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:46,464] Trial 143 finished with value: 47.93767159186078 and parameters: {'eta': 0.6429086912814764, 'max_depth': 1, 'min_gain_to_split': 0.002563657663319008, 'subsample': 0.27323075745439196, 'feature_fraction': 0.6940769421682917, 'boosting': 'gbdt'}. Best is trial 109 with value: 47.76294404698272.
# [I 2023-06-15 15:08:47,607] Trial 144 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:48,800] Trial 145 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:49,902] Trial 146 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:51,166] Trial 147 pruned. Trial was pruned at iteration 21.
# [I 2023-06-15 15:08:52,282] Trial 148 pruned. Trial was pruned at iteration 21.
# [I 2023-06-15 15:08:53,365] Trial 149 pruned. Trial was pruned at iteration 21.
# [I 2023-06-15 15:08:54,428] Trial 150 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:08:55,547] Trial 151 pruned. Trial was pruned at iteration 21.
# [I 2023-06-15 15:08:56,567] Trial 152 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:09:01,764] Trial 153 finished with value: 49.427772998680645 and parameters: {'eta': 0.3019024521676184, 'max_depth': 1, 'min_gain_to_split': 0.02068272371525686, 'subsample': 0.2846726827704053, 'feature_fraction': 0.8037053656903663, 'boosting': 'gbdt'}. Best is trial 109 with value: 47.76294404698272.
# [I 2023-06-15 15:09:02,844] Trial 154 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:09:05,981] Trial 155 finished with value: 50.56724182583806 and parameters: {'eta': 0.2182616577019899, 'max_depth': 1, 'min_gain_to_split': 1.4466820750414102, 'subsample': 0.32404043542020666, 'feature_fraction': 0.8152866724371032, 'boosting': 'gbdt'}. Best is trial 109 with value: 47.76294404698272.
# [I 2023-06-15 15:09:07,181] Trial 156 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:09:08,350] Trial 157 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:09:09,533] Trial 158 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:09:10,701] Trial 159 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:09:11,967] Trial 160 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:09:13,278] Trial 161 pruned. Trial was pruned at iteration 23.
# [I 2023-06-15 15:09:14,526] Trial 162 pruned. Trial was pruned at iteration 21.
# [I 2023-06-15 15:09:15,761] Trial 163 pruned. Trial was pruned at iteration 23.
# [I 2023-06-15 15:09:16,839] Trial 164 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:09:18,014] Trial 165 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:09:19,064] Trial 166 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:09:20,311] Trial 167 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:09:21,421] Trial 168 pruned. Trial was pruned at iteration 20.
# [I 2023-06-15 15:09:22,484] Trial 169 pruned. Trial was pruned at iteration 20.
#
# Hyper-Parameter Optimization successfully finished.
#   Number of finished trials:  170
#   Best trial:
#     Value: 47.76294404698272
#     Params:
#     eta: 0.11822840706436007
#     max_depth: 2
#     min_gain_to_split: 0.8165464594469042
#     subsample: 0.45276400454388877
#     feature_fraction: 0.7945577994601252
#     boosting: gbdt
#     opt_rounds: 45

# %% [markdown]
# # Model Training

# %%
np.random.seed(123)

opt_params = opt_param.copy()
n_rounds = opt_params["opt_rounds"]
del opt_params["opt_rounds"]

# Train Model with optimized hyperparameters
lgblss.train(opt_params,
             dtrain,
             num_boost_round=n_rounds
             )

# %% [markdown]
# # Prediction

# %%
# Set seed for reproducibility
torch.manual_seed(123)

# Number of samples to draw from predicted distribution
n_samples = 1000
# Quantiles to calculate from predicted distribution
quant_sel = [0.05, 0.95] 

# Sample from predicted distribution
pred_samples = lgblss.predict(X_test,
                              pred_type="samples",
                              n_samples=n_samples,
                              seed=123)

# Calculate quantiles from predicted distribution
pred_quantiles = lgblss.predict(X_test,
                                pred_type="quantiles",
                                n_samples=n_samples,
                                quantiles=quant_sel)

# Returns predicted distributional parameters
pred_params = lgblss.predict(X_test,
                             pred_type="parameters")

# %%
pred_samples.head()
# Out:
#    y_sample0  y_sample1  y_sample2  y_sample3  y_sample4  y_sample5
# 0          1          0         17          9          3          0  \
# 1          0          0          0          0          0          0
# 2          1         44         47          3         30         15
# 3         10         10         71          0         21         19
# 4          0          0          0          2          0          0
#
#    y_sample6  y_sample7  y_sample8  y_sample9  ...  y_sample990  y_sample991
# 0          2          6          2          0  ...            2            0  \
# 1          0          0          0          0  ...            0            0
# 2          0          0         32          7  ...           13           41
# 3          3         34          0        179  ...           28            6
# 4          2          1          4          2  ...            1            5
#
#    y_sample992  y_sample993  y_sample994  y_sample995  y_sample996
# 0           21            8            0           71            4  \
# 1            0            0            0            0            0
# 2          109            0           30            1          379
# 3          184            3            1           84          258
# 4            0            1            4            0            8
#
#    y_sample997  y_sample998  y_sample999
# 0            1            0            0
# 1            0            0            0
# 2            3            8           17
# 3            3            7           79
# 4            4            1            6
#
# [5 rows x 1000 columns]

# %%
pred_quantiles.head()
# Out:
#    quant_0.05  quant_0.95
# 0           0          14
# 1           0           0
# 2           0         117
# 3           0         175
# 4           0           7

# %%
pred_params.head()
# Out:
#    total_count     probs   gate
# 0     0.311453  0.909880  0.001
# 1     0.014769  0.600037  0.001
# 2     0.313132  0.987071  0.001
# 3     0.297513  0.991554  0.001
# 4     0.296796  0.827654  0.001

# %% [markdown]
# # SHAP Interpretability

# %%
# Partial Dependence Plot of rate parameter
lgblss.plot(X_test,
            parameter="total_count",
            feature="persons",
            plot_type="Partial_Dependence")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# Feature Importance of gate parameter
lgblss.plot(X_test,
            parameter="probs",
            plot_type="Feature_Importance")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# # Density Plots of Actual and Predicted Samples

# %%
pred_df = pd.melt(pred_samples.iloc[:,0:5])
actual_df = pd.DataFrame.from_dict({"variable": "ACTUAL", "value": y_test.reshape(-1,)})
plot_df = pd.concat([pred_df, actual_df])

(
    ggplot(plot_df, 
           aes(x="value",
               color="variable",
               fill="variable")) +  
    geom_density(alpha=0.4) + 
    facet_wrap("variable",
              scales="free",
              ncol=2) + 
    theme_bw(base_size=15) + 
    theme(legend_position="none")
)
# Out:
# <Figure Size: (1800 x 900)>
